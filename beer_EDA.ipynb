# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import pickle

with open('beer.pickle','rb') as read_file:
    beer_df = pickle.load(read_file)
beer_df.head()
# Out:
#    beerid                                          name  \
# 0       1                             Vanilla Cream Ale
# 1       2                   Southern Tier Pumking clone
# 2       5               Bakke Brygg Belgisk Blonde 50 l
# 3       6                  Sierra Nevada Pale Ale Clone
# 4       8  Spotted Clown (New Glarus Spotted Cow clone)
#
#                                 style  styleid   size     og     fg   abv  \
# 0                           Cream Ale       45  21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85  20.82  1.083  1.021  8.16
# 2                   Belgian Blond Ale       20  50.00  1.060  1.010  6.48
# 3                   American Pale Ale       10  24.61  1.055  1.013  5.58
# 4                           Cream Ale       45  20.82  1.054  1.014  5.36
#
#      ibu  color  ...   cider  saison  kolsch  ale gose  barleywine  apa  \
# 0  17.65   4.83  ...       0       0       0    1    0           0    0
# ...

# %%
beer_df.columns
# Out:
# Index(['beerid', 'name', 'style', 'styleid', 'size', 'og', 'fg', 'abv', 'ibu',
#        'color', 'boilsize', 'boiltime', 'boilgravity', 'efficiency',
#        'brewmethod', 'allgrain', 'biab', 'partialmash', 'extract', 'style',
#        'styleid', 'ipa', 'lager', 'stout', 'porter', 'cider', 'saison',
#        'kolsch', 'ale', 'gose', 'barleywine', 'apa', 'wheat', 'pilsner',
#        'other'],
#       dtype='object')

# %%
beer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70517 entries, 0 to 70516
# Data columns (total 35 columns):
# beerid         70517 non-null int64
# name           70516 non-null object
# style          70517 non-null object
# styleid        70517 non-null int64
# size           70517 non-null float64
# og             70517 non-null float64
# fg             70517 non-null float64
# abv            70517 non-null float64
# ibu            70517 non-null float64
# color          70517 non-null float64
# boilsize       70517 non-null float64
# boiltime       70517 non-null int64
# boilgravity    70517 non-null float64
# efficiency     70517 non-null float64
# brewmethod     70517 non-null object
# allgrain       70517 non-null int64
# biab           70517 non-null int64
# partialmash    70517 non-null int64
# extract        70517 non-null int64
# style          70517 non-null object
# styleid        70517 non-null int64
# ipa            70517 non-null int64
# ...

# %%
#Check that the data makes sense

# %%
beer_df.iloc[:,4:22].drop(columns = ['brewmethod', 'style', 'styleid']).groupby('ipa').mean()
# Out:
#           size        og        fg       abv        ibu      color   boilsize  \
# ipa
# 0    45.428452  1.412307  1.077623  5.958549  34.998843  14.425116  51.393535
# 1    42.908740  1.426491  1.075957  6.698507  76.670365   9.805047  48.783951
#
#       boiltime  boilgravity  efficiency  allgrain      biab  partialmash  \
# ipa
# 0    65.342856     1.350537   66.280030  0.672493  0.169095     0.045046
# 1    64.472071     1.359547   66.030279  0.679086  0.163153     0.043015
#
#       extract
# ipa
# 0    0.113366
# 1    0.114746

# %%
beer_df.iloc[:,4:23].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa']).groupby('lager').mean()
# Out:
#             size        og        fg       abv        ibu      color  \
# lager
# 0      43.270369  1.412523  1.077194  6.172073  45.675073  13.610706
# 1      70.389340  1.466189  1.077870  5.474833  29.729610   8.993460
#
#         boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# lager
# 0      49.160568  65.192312     1.348678   66.245689  0.673836  0.168004
# 1      77.210674  64.270966     1.417301   65.828629  0.677293  0.162825
#
#        partialmash   extract
# lager
# 0         0.045079  0.113081
# 1         0.036292  0.123590

# %%
beer_df.iloc[:,4:24].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager']).groupby('stout').mean()
# Out:
#             size        og        fg       abv        ibu      color  \
# stout
# 0      45.245732  1.404963  1.072955  6.053617  44.205998  11.034469
# 1      40.207028  1.536957  1.125909  7.020762  50.976089  39.617827
#
#         boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# stout
# 0      51.201746  65.009997     1.343470   66.259298  0.674483  0.167726
# 1      46.014913  66.607162     1.457049   65.792313  0.668949  0.167457
#
#        partialmash   extract
# stout
# 0         0.044045  0.113746
# 1         0.050553  0.113042

# %%
beer_df.iloc[:,4:25].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager', 'stout']).groupby('porter').mean()
# Out:
#              size        og        fg       abv        ibu      color  \
# porter
# 0       44.731700  1.412814  1.076417  6.131778  44.994119  12.587017
# 1       47.660819  1.489845  1.098765  6.131056  38.389561  33.308703
#
#          boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# porter
# 0       50.672437  65.155059     1.350184   66.211258  0.673589  0.167923
# 1       53.692194  64.716117     1.417621   66.493670  0.685825  0.161942
#
#         partialmash   extract
# porter
# 0          0.044553  0.113935
# 1          0.045049  0.107184

# %%
beer_df.iloc[:,4:26].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager', 'stout']).groupby('cider').mean()
# Out:
#             size        og        fg       abv        ibu      color  \
# cider
# 0      44.903988  1.416183  1.077371  6.129292  44.852259  13.357681
# 1      18.275665  1.189314  1.021253  7.132023   4.371445   7.655145
#
#         boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# cider
# 0      50.864346  65.228349     1.353340   66.242302  0.674827  0.167861
# 1      17.587225  28.820809     1.070624   57.791908  0.352601  0.104046
#
#        partialmash   extract    porter
# cider
# 0         0.044510  0.112803  0.036606
# 1         0.069364  0.473988  0.000000

# %%
beer_df.iloc[:,4:27].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager', 'stout', 'cider']).groupby('saison').mean()
# Out:
#              size        og        fg       abv        ibu      color  \
# saison
# 0       44.817286  1.420019  1.078543  6.134109  45.300691  13.595328
# 1       45.413509  1.297499  1.042009  6.068370  30.021693   6.576068
#
#          boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# saison
# 0       50.722166  65.055435     1.356535   66.171770  0.673256  0.166983
# 1       52.410906  67.387263     1.248058   67.560918  0.695016  0.187104
#
#         partialmash   extract    porter
# saison
# 0          0.044743  0.115019  0.037874
# 1          0.039953  0.077927  0.000000

# %%
beer_df.iloc[:,4:28].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager','stout', 'cider', 'saison']).groupby('kolsch').mean()
# Out:
#              size        og        fg       abv        ibu      color  \
# kolsch
# 0       44.913308  1.415494  1.077305  6.145403  44.983862  13.454873
# 1       38.646702  1.426679  1.071310  4.999429  25.598786   4.121250
#
#          boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# kolsch
# 0       50.861761  65.064856     1.352568   66.198524  0.673508  0.167717
# 1       44.225226  71.291667     1.359102   68.133214  0.717857  0.166667
#
#         partialmash   extract    porter
# kolsch
# 0          0.044678  0.114098  0.036956
# 1          0.035714  0.079762  0.000000

# %%
beer_df.iloc[:,4:29].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager','stout', 'cider', 'kolsch']).groupby('ale').mean()
# Out:
#           size        og        fg       abv        ibu      color   boilsize  \
# ale
# 0    44.700666  1.424933  1.078642  6.159481  46.840588  13.417326  50.581331
# 1    45.602433  1.364118  1.069439  5.978277  33.198278  12.936132  51.897280
#
#       boiltime  boilgravity  efficiency  allgrain      biab  partialmash  \
# ale
# 0    65.035931     1.359764   66.218168  0.673141  0.168704     0.044420
# 1    65.709665     1.313249   66.240404  0.678992  0.162172     0.045408
#
#       extract    porter    saison
# ale
# 0    0.113736  0.043114  0.042327
# 1    0.113428  0.000000  0.000000

# %%
beer_df.iloc[:,4:30].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager','stout', 'cider', 'kolsch','ale']).groupby('gose').mean()
# Out:
#            size        og        fg       abv        ibu      color  \
# gose
# 0     44.863712  1.416110  1.077333  6.134844  44.828925  13.362627
# 1     32.846259  1.184403  1.029686  4.651429   8.381701   4.278776
#
#        boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# gose
# 0     50.810062  65.157979     1.353073   66.220186  0.674009  0.167685
# 1     37.687551  56.068027     1.148143   66.884354  0.687075  0.176871
#
#       partialmash   extract    porter    saison
# gose
# 0        0.044607  0.113699  0.036592  0.035924
# 1        0.027211  0.108844  0.000000  0.000000

# %%
beer_df.iloc[:,4:31].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager','stout', 'cider', 'kolsch', 'ale','gose']).groupby('barleywine').mean()
# Out:
#                  size        og        fg        abv        ibu      color  \
# barleywine
# 0           44.858975  1.412751  1.076496   6.096003  44.443617  13.311854
# 1           42.314529  1.773005  1.168783  10.573677  83.187869  17.299503
#
#              boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# barleywine
# 0           50.786803  64.966178     1.350722   66.220856  0.673342  0.167925
# 1           50.273677  86.616341     1.591709   66.310302  0.760213  0.140320
#
#             partialmash   extract   porter    saison
# barleywine
# 0              0.044529  0.114204  0.03681  0.036138
# 1              0.049734  0.049734  0.00000  0.000000

# %%
beer_df.iloc[:,4:32].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager','stout', 'cider', 'kolsch', 'ale','gose', 'barleywine']).groupby('apa').mean()
# Out:
#          size        og        fg       abv        ibu      color   boilsize  \
# apa
# 0    45.08167  1.420899  1.078726  6.209511  44.819438  14.058572  51.057171
# 1    42.74320  1.370169  1.064362  5.461235  44.179599   7.179303  48.416013
#
#       boiltime  boilgravity  efficiency  allgrain      biab  partialmash  \
# apa
# 0    65.462675     1.356458   66.190754  0.676589  0.165345     0.044786
# 1    62.348253     1.319772   66.487295  0.652020  0.188046     0.042713
#
#       extract    porter    saison
# apa
# 0    0.113279  0.040751  0.040007
# 1    0.117222  0.000000  0.000000

# %%
beer_df.iloc[:,4:33].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager','stout', 'cider', 'kolsch', 'ale', 'gose', 'barleywine', 'apa']).groupby('wheat').mean()
# Out:
#             size        og        fg       abv        ibu      color  \
# wheat
# 0      44.940593  1.416995  1.077917  6.196809  46.550667  13.896207
# 1      43.380020  1.396045  1.067449  5.200790  19.027901   5.437282
#
#         boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# wheat
# 0      50.942640  65.223347     1.353487   66.275383  0.674789  0.166831
# 1      48.494086  63.932479     1.340609   65.451520  0.663265  0.180200
#
#        partialmash   extract    porter    saison
# wheat
# 0         0.044772  0.113608  0.039068  0.038355
# 1         0.041685  0.114850  0.000000  0.000000

# %%
beer_df.iloc[:,4:34].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager','stout', 'cider',  'kolsch', 'ale','gose', 'barleywine', 'apa', 'wheat']).groupby('pilsner').mean()
# Out:
#               size        og        fg       abv        ibu      color  \
# pilsner
# 0        44.860623  1.416182  1.077473  6.143189  44.882780  13.472200
# 1        43.286657  1.376430  1.060308  5.323567  35.578435   4.262785
#
#           boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# pilsner
# 0        50.827495  65.036889     1.353199   66.196427  0.673249  0.168064
# 1        47.617795  72.356707     1.313606   67.998283  0.729675  0.142276
#
#          partialmash   extract    porter    saison
# pilsner
# 0           0.044583  0.114104  0.037033  0.036357
# 1           0.043699  0.084350  0.000000  0.000000

# %%
beer_df.iloc[:,4:35].drop(columns = ['brewmethod', 'style', 'styleid', 'ipa', 'lager','stout', 'cider',  'kolsch', 'ale','gose', 'barleywine', 'apa', 'wheat', 'pilsner']).groupby('other').mean()
# Out:
#             size        og        fg       abv        ibu      color  \
# other
# 0      45.302162  1.417191  1.077497  6.156934  47.995031  13.433041
# 1      42.916586  1.409142  1.076140  6.027325  31.308509  12.973171
#
#         boilsize   boiltime  boilgravity  efficiency  allgrain      biab  \
# other
# 0      51.254292  65.056393     1.355753   66.178060  0.675444  0.168298
# 1      48.827114  65.481717     1.339762   66.402001  0.668199  0.165243
#
#        partialmash   extract    porter    saison
# other
# 0         0.043562  0.112697  0.045322  0.044495
# 1         0.048756  0.117802  0.000000  0.000000

# %%
beer_counts = beer_df.iloc[:,21:].sum()

# %%
beer_counts
# Out:
# ipa           16506
# lager          4078
# stout          5697
# porter         2575
# cider           173
# saison         2528
# kolsch          840
# ale           10791
# gose            147
# barleywine      563
# apa            7328
# wheat          4606
# pilsner         984
# other         13701
# dtype: int64

# %%
beer_counts.sum()
# Out:
# 70517

# %%
pd.Series.apply(beer_counts, lambda x: x / beer_counts.sum())
# Out:
# ipa           0.234071
# lager         0.057830
# stout         0.080789
# porter        0.036516
# cider         0.002453
# saison        0.035850
# kolsch        0.011912
# ale           0.153027
# gose          0.002085
# barleywine    0.007984
# apa           0.103918
# wheat         0.065318
# pilsner       0.013954
# other         0.194294
# dtype: float64

# %%
np.add(np.add(np.add(np.add(beer_df['cider'].sum(),beer_df['kolsch'].sum()),beer_df['gose'].sum()), beer_df['barleywine'].sum()), beer_df['pilsner'].sum())
# Out:
# 2707

# %%
2707/70517
# Out:
# 0.03838790646227151

# %%
beer_df[beer_df.ale == 1]['style'].iloc[:,0].value_counts()
# Out:
# American Amber Ale              1937
# Blonde Ale                      1693
# Irish Red Ale                   1145
# American Brown Ale              1080
# Cream Ale                        790
# Belgian Pale Ale                 609
# Belgian Dark Strong Ale          519
# Belgian Blond Ale                482
# British Brown Ale                390
# Belgian Specialty Ale            384
# Belgian Golden Strong Ale        338
# Old Ale                          279
# British Golden Ale               271
# American Strong Ale              227
# Strong Scotch Ale                204
# British Strong Ale               195
# Flanders Red Ale                 141
# Flanders Brown Ale/Oud Bruin      50
# Australian Sparkling Ale          49
# London Brown Ale                   8
# Name: style, dtype: int64

# %%
beer_df.color.hist();

plt.title('Histogram of Beer Color');
plt.xlabel('Color');
plt.ylabel('Frequency');

# %%
beer_df.abv.hist();

plt.title('Histogram of ABV');
plt.xlabel('ABV');
plt.ylabel('Frequency');

# %%
beer_df.abv.hist(bins = 20);

plt.title('Histogram of ABV');
plt.xlim(15,50)
plt.ylim(0,200)
plt.xlabel('ABV');
plt.ylabel('Frequency');

# %%
beer_df['abv'].max()
# Out:
# 54.72

# %%
beer_df.sort_values(by = 'abv', ascending = False)
# Out:
#        beerid                                name  \
# 22919   25941                           Skåpsrens
# 7725     9942                        FBTCZECHBEER
# 45371   48527                            BCBD RIS
# 24170   27205                           Tuna Beer
# 26575   29633                           Black ipa
# 1547     2298                         Vedo triplo
# 5892     7778                            Belgbert
# 69250   72582                    Juicy Jill NEIPA
# 13502   16347                               Brown
# 70294   73636                      Awesome Recipe
# 34571   37668                 CATALINA WEIZENBOCK
# 4562     6153                      Awesome Recipe
# 2230     3228                        CHEESE SNACK
# 61369   64644                  #49 American Stout
# 59928   63192                      Awesome Recipe
# 8484    10808                  Festive Spawn 2015
# 14782   17684                           Boltmaker
# 13424   16268                   Trælaramp IPA 002
# ...

# %%
beer_df.ibu.hist();

plt.title('Histogram of IBU');
plt.xlabel('IBU');
plt.ylabel('Frequency');

# %%
beer_df.ibu.hist(bins = 20);

plt.title('Histogram of IBU');
plt.xlim(500,3500)
plt.ylim(0,10)
plt.xlabel('IBU');
plt.ylabel('Frequency');

# %%
beer_df['ibu'].describe()
# Out:
# count    70517.000000
# mean        44.752947
# std         41.310599
# min          0.000000
# 25%         23.920000
# 50%         36.170000
# 75%         56.750000
# max       3409.300000
# Name: ibu, dtype: float64

# %%
beer_df['ibu'].max()
# Out:
# 3409.3

# %%
beer_df.sort_values(by = 'ibu', ascending = False)
# Out:
#        beerid                                   name  \
# 45371   48527                               BCBD RIS
# 3789     5215                         Citra pale ale
# 2340     3378                            Smash NEIPA
# 24219   27254                             Summer IPA
# 67480   70798                              Cream IPA
# 9452    11903                        HelloW Pale Ale
# 4765     6409                Imperial IPA (To Je To)
# 65068   68367                             Pale lager
# 65424   68729            Starry Knight Bourbon Stout
# 68316   71637                            Cascade IPA
# 4482     6053                           Heady Topper
# 1621     2395            Chocolate Milk Porter/Stout
# 17422   20390                            PtY Clone^2
# 3994     5472                Stone Enjoy by 12.11.15
# 26061   29116                            HOP BONANZA
# 5465     7267                        Dead Ringer Ale
# 16259   19208         What the hell is wrong with me
# ...

# %%
#Drop 'Other' category

beer_df_2 = beer_df[beer_df.other == 0]

# %%
beer_df_2.head(1)
# Out:
#    beerid               name      style  styleid   size     og     fg   abv  \
# 0       1  Vanilla Cream Ale  Cream Ale       45  21.77  1.055  1.013  5.48
#
#      ibu  color  ...   cider  saison  kolsch  ale gose  barleywine  apa  \
# 0  17.65   4.83  ...       0       0       0    1    0           0    0
#
#    wheat  pilsner other
# 0      0        0     0
#
# [1 rows x 35 columns]

# %%
new_beer_counts = beer_df_2.iloc[:,21:].sum()

# %%
new_beer_counts
# Out:
# ipa           16506
# lager          4078
# stout          5697
# porter         2575
# cider           173
# saison         2528
# kolsch          840
# ale           10791
# gose            147
# barleywine      563
# apa            7328
# wheat          4606
# pilsner         984
# other             0
# dtype: int64

# %%
new_beer_counts.sum()
# Out:
# 56816

# %%
pd.Series.apply(new_beer_counts, lambda x: x / new_beer_counts.sum())
# Out:
# ipa           0.290517
# lager         0.071776
# stout         0.100271
# porter        0.045322
# cider         0.003045
# saison        0.044495
# kolsch        0.014785
# ale           0.189929
# gose          0.002587
# barleywine    0.009909
# apa           0.128978
# wheat         0.081069
# pilsner       0.017319
# other         0.000000
# dtype: float64

# %%
#Also drop Gose, Cider and Barleywine

filtered_ids = list(beer_df[(beer_df.other == 1) | (beer_df.cider == 1)| (beer_df.gose == 1) |(beer_df.barleywine == 1)].beerid)

# %%
#flip signs of beer filter above

beer_mask = beer_df.beerid.isin(filtered_ids) == False

# %%
final_beer_df = beer_df[beer_mask]

# %%
final_beer_df
# Out:
#        beerid                                          name  \
# 0           1                             Vanilla Cream Ale
# 2           5               Bakke Brygg Belgisk Blonde 50 l
# 3           6                  Sierra Nevada Pale Ale Clone
# 4           8  Spotted Clown (New Glarus Spotted Cow clone)
# 5           9                      Chocolate Vanilla Porter
# 6          10                            Mango Habanero IPA
# 7          11                     Bakke Brygg HveteIPA 25 L
# 8          14                     Sam Adams Rebel IPA Clone
# 9          15                                     White IPA
# 10         17                                  Tank 7 Clone
# 11         18                       Bells two hearted clone
# 13         20            Avg. Perfect Northeast IPA (NEIPA)
# 14         21                        Goose Island IPA Clone
# 15         22               Ballast Point Sculpin Ale Clone
# 16         24                           Lagunitas IPA Clone
# ...

# %%
final_beer_counts = final_beer_df.iloc[:,21:].sum()
final_beer_counts
# Out:
# ipa           16506
# lager          4078
# stout          5697
# porter         2575
# cider             0
# saison         2528
# kolsch          840
# ale           10791
# gose              0
# barleywine        0
# apa            7328
# wheat          4606
# pilsner         984
# other             0
# dtype: int64

# %%
final_beer_counts.sum()
# Out:
# 55933

# %%
pd.Series.apply(final_beer_counts, lambda x: x / final_beer_counts.sum())
# Out:
# ipa           0.295103
# lager         0.072909
# stout         0.101854
# porter        0.046037
# cider         0.000000
# saison        0.045197
# kolsch        0.015018
# ale           0.192927
# gose          0.000000
# barleywine    0.000000
# apa           0.131014
# wheat         0.082349
# pilsner       0.017592
# other         0.000000
# dtype: float64

# %%
final_beer_df = final_beer_df.drop(columns = ['cider', 'gose', 'barleywine', 'other'])

# %%
print('Original total data:', beer_counts.sum())
# Out:
# Original total data: 70517

# %%
print('Other data:', beer_counts['other'])
print('Adjusted total data:',(beer_counts.sum() - beer_counts['other']))
# Out:
# Other data: 13701
# Adjusted total data: 56816

# %%
print('Percent of adjusted dataset used:', final_beer_counts.sum() / np.round((beer_counts.sum() - beer_counts['other']),decimals = 10))
# Out:
# Percent of adjusted dataset used: 0.9844586032103633

# %%
with open ('beer_final.pickle', 'wb') as to_write:
    pickle.dump(final_beer_df, to_write)
